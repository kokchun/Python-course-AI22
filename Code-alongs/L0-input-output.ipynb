# %% [markdown]
# # Code along - input-output

# %%
# variable - data type string
# create a variable ("box") and assigns a value
name = "Kokchun"

# variable - data type float
age = 31.4

# this is an f-string (formatted string)
print(f"hej {name}, du är {age} gammal")

# reassigns 
# note: bad practice 
name = 20

print(name)
# Out:
# hej Kokchun, du är 31.4 gammal
# 20

# %% [markdown]
# ## Inputs from user

# %%
name = input("What is your name?")
age = input("What is your age?")

print(f"Hello {name}, you are {age} years old")
# Out:
# Hello Hanna, you are 18 old

# %% [markdown]
# ## Calculations

# %%
gravity = 9.82
mass = 62

force = mass*gravity

print(f"Your force is {force} N")
# Out:
# Your force is 608.84 N

# %%
mass = input("Enter your mass (kg): ") # string

# can't multiply string with a float
force = mass*gravity
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\kokch\OneDrive\Dokument\GitHub\AI22\Python-course-AI22\Code-alongs\L0-input-output.ipynb Cell 7 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/kokch/OneDrive/Dokument/GitHub/AI22/Python-course-AI22/Code-alongs/L0-input-output.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> mass = input("Enter your mass (kg): ")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/kokch/OneDrive/Dokument/GitHub/AI22/Python-course-AI22/Code-alongs/L0-input-output.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> force = mass*gravity
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
mass = float(input("Enter your mass (kg): ")) # string

# can't multiply string with a float
force = mass*gravity

# :.1f -> rounds to 1 decimal
print(f"{force=:.1f}N")
# <=> print(f"force={force:.1f}N")

# in order to print {} curly brackets
print(f"{force} \u007b \u007d")
print(f"{{}}")
# Out:
# force=608.8N
