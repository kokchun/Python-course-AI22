# %% [markdown]
# # Plotting
#
# - x = [x1, x2, ... ,xn]
# - y = [y1, y2, ... ,yn]
#
# ```py
# plt.plot(x,y)
# ```

# %%
import matplotlib.pyplot as plt 

pichu_height = [21, 21, 20, 15, 10]
pichu_width = [28, 31, 15, 15, 10]
pikachu_height = [31, 51, 40, 35, 20]
pikachu_width = [25, 29, 40, 45, 30]


plt.plot(pichu_width, pichu_height, '*')
plt.plot(pikachu_width, pikachu_height, 'o')
plt.legend(["Pichu", "Pikachu"])

# %%
width = {"pika_width": [21, 13, 31], "pichu_width": [3,45,6]}
width["pika_width"]
# Out:
# [21, 13, 31]

# %%
import random as rnd
import matplotlib.pyplot as plt

pokemon = [
    [rnd.randint(20, 30) for _ in range(200)], # width
    [rnd.randint(15, 30) for _ in range(200)], # height
    [rnd.randint(0,1) for _ in range(200)], # label
]

plt.scatter(pokemon[0], pokemon[1], c = pokemon[2])
len(pokemon)
# width, height, c=type
# Out:
# 3

# %%
import numpy as np
pokemon_list2 = [
    [rnd.randint(20, 35), rnd.randint(20, 35), rnd.randint(0, 1)] for _ in range(200)
]

pokemon_array = np.array(pokemon_list2)

plt.scatter(pokemon_array[:,0],pokemon_array[:,1], c = pokemon_array[:,-1]  )

# %%
test_lista = [["212", "32", "1"], ["23", "15", "14"] ]

# %%
import numpy as np
import matplotlib.pyplot as plt
from dataclasses import dataclass

@dataclass
class Sine:
    x: np.array

    def plot(self, ax):
        ax.plot(np.sin(self.x))

@dataclass
class Line:
    x: np.array
    slope: int = 1
    intercept: int = 0

    def plot(self, ax):
        ax.plot(self.slope*self.x + self.intercept)

ax = plt.axes()
my_sine = Sine(np.linspace(-3,3))
my_line = Line(np.linspace(-3,3))
neg_line = Line(np.linspace(-3,3), slope = -1)

for func in (my_line, my_sine, neg_line):
    func.plot(ax)

ax.set(title = "Drawing many functions in same surface");
# Out:
# [Text(0.5, 1.0, 'Drawing many functions in same surface')]
